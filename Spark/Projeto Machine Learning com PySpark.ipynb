# %% [markdown]
# O projeto proposto será nós trabalharmos com um dataframe do SP500, índice americano que representa ativos negociados na NYSE e na NASDAQ. Nesse dataframe, temos informações a respeito da cotação de abertura, máxima, mínima, volume, fechamento e ajuste do fechamento, do ativo.

# %% [markdown]
# Trabalharemos um modelo de machine learning por regressão linear, com o objetivo de prevermos o valor de fechamento do ativo, com base em alguns atributos supracitadas do dataframe.

# %% [markdown]
# O primeiro passo é instalar o pyspark em nossa VM e importá-lo.

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=5f4621db46e734eb7bf8ef517b8affa99e45fc24ec23c5dd19774d6a11d82367
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
import pyspark

# %% [markdown]
# Do módulo pyspark SQL importamos o SparkSession para criar nossa sessão.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %% [markdown]
# Atribuímos a um objeto nossa sessão criada.

# %%
spark = SparkSession.builder.master('local').appName('sp500').getOrCreate()

# %% [markdown]
# Chamamos nosso dataframe pelo método read para visualizá-lo e contamos quantas linhas tem.

# %%
df = spark.read.csv('/content/SP500data.csv', header=True, inferSchema=True)
df.show(10, truncate=False)
df.count()
# Out:
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+
# |_c0|Date      |High              |Low               |Open              |Close             |Volume    |Adj Close         |Symbol|
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+
# |0  |2010-01-04|30.64285659790039 |30.34000015258789 |30.489999771118164|30.572856903076172|1.234324E8|26.68132972717285 |AAPL  |
# |1  |2010-01-04|34.099998474121094|33.400001525878906|33.599998474121094|34.0              |4.06793E7 |31.601511001586914|C     |
# |2  |2010-01-04|32.709999084472656|32.23500061035156 |32.290000915527344|32.69499969482422 |5894200.0 |26.618066787719727|UNP   |
# |3  |2010-01-04|59.189998626708984|57.5099983215332  |57.650001525878906|58.54999923706055 |7325600.0 |43.9952392578125  |CAT   |
# |4  |2010-01-04|28.31999969482422 |27.665000915527344|28.31999969482422 |27.8700008392334  |4832000.0 |27.8700008392334  |CELG  |
# |5  |2010-01-04|31.600000381469727|30.969999313354492|31.3799991607666  |31.530000686645508|1.21995E7 |27.110151290893555|UNH   |
# |6  |2010-01-04|41.439998626708984|40.93000030517578 |41.244998931884766|41.42499923706055 |4874200.0 |32.923980712890625|CL    |
# |7  |2010-01-04|26.610000610351562|25.889999389648438|26.200000762939453|26.010000228881836|1.03693E7 |20.337688446044922|TXN   |
# |8  |2010-01-04|8.5649995803833   |8.375             |8.375             |8.484999656677246 |2.71468E7 |7.081010341644287 |CMCSA |
# |9  |2010-01-04|25.700000762939453|25.299999237060547|25.40999984741211 |25.6299991607666  |1.43761E7 |18.61980438232422 |BMY   |
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+
# only showing top 10 rows
# 34721

# %% [markdown]
# Checamos os tipos de dados de nosso dataframe.

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: double (nullable = true)
#  |-- Adj Close: double (nullable = true)
#  |-- Symbol: string (nullable = true)

# %% [markdown]
# Aqui nós importamos os Vectors e o VectorAssembler, para posteriormente usar em nossa base de dados para criarmos um dataframe vetorizado.

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

# %% [markdown]
# Aqui nós utizamos o transformador Vector Assembler nos atributos que escolhemos para criar nossa coluna vetorizada. Através dos dados dessas colunas escolhidas, nosso modelo irá tentar prever o valor de fechamento do ativo, objetivo do nosso projeto.

# %%
assembler = VectorAssembler(inputCols=["Open", "High", "Low", "Volume"], outputCol="features")
print(assembler)
# Out:
# VectorAssembler_91f263e0964c

# %% [markdown]
# Abaixo nós aplicamos um transform no objeto assembler, para que ele crie nossa coluna features vetorizada.

# %%
df_novo = assembler.transform(df)
df_novo.show(15, truncate=False)
# Out:
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+--------------------------------------------------------------------+
# |_c0|Date      |High              |Low               |Open              |Close             |Volume    |Adj Close         |Symbol|features                                                            |
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+--------------------------------------------------------------------+
# |0  |2010-01-04|30.64285659790039 |30.34000015258789 |30.489999771118164|30.572856903076172|1.234324E8|26.68132972717285 |AAPL  |[30.489999771118164,30.64285659790039,30.34000015258789,1.234324E8] |
# |1  |2010-01-04|34.099998474121094|33.400001525878906|33.599998474121094|34.0              |4.06793E7 |31.601511001586914|C     |[33.599998474121094,34.099998474121094,33.400001525878906,4.06793E7]|
# |2  |2010-01-04|32.709999084472656|32.23500061035156 |32.290000915527344|32.69499969482422 |5894200.0 |26.618066787719727|UNP   |[32.290000915527344,32.709999084472656,32.23500061035156,5894200.0] |
# |3  |2010-01-04|59.189998626708984|57.5099983215332  |57.650001525878906|58.54999923706055 |7325600.0 |43.9952392578125  |CAT   |[57.650001525878906,59.189998626708984,57.5099983215332,7325600.0]  |
# |4  |2010-01-04|28.31999969482422 |27.665000915527344|28.31999969482422 |27.8700008392334  |4832000.0 |27.8700008392334  |CELG  |[28.31999969482422,28.31999969482422,27.665000915527344,4832000.0]  |
# |5  |2010-01-04|31.600000381469727|30.969999313354492|31.3799991607666  |31.530000686645508|1.21995E7 |27.110151290893555|UNH   |[31.3799991607666,31.600000381469727,30.969999313354492,1.21995E7]  |
# |6  |2010-01-04|41.439998626708984|40.93000030517578 |41.244998931884766|41.42499923706055 |4874200.0 |32.923980712890625|CL    |[41.244998931884766,41.439998626708984,40.93000030517578,4874200.0] |
# |7  |2010-01-04|26.610000610351562|25.889999389648438|26.200000762939453|26.010000228881836|1.03693E7 |20.337688446044922|TXN   |[26.200000762939453,26.610000610351562,25.889999389648438,1.03693E7]|
# |8  |2010-01-04|8.5649995803833   |8.375             |8.375             |8.484999656677246 |2.71468E7 |7.081010341644287 |CMCSA |[8.375,8.5649995803833,8.375,2.71468E7]                             |
# |9  |2010-01-04|25.700000762939453|25.299999237060547|25.40999984741211 |25.6299991607666  |1.43761E7 |18.61980438232422 |BMY   |[25.40999984741211,25.700000762939453,25.299999237060547,1.43761E7] |
# |10 |2010-01-04|39.13999938964844 |38.54999923706055 |38.65999984741211 |39.04999923706055 |4447400.0 |33.58551788330078 |COF   |[38.65999984741211,39.13999938964844,38.54999923706055,4447400.0]   |
# |11 |2010-01-04|40.158836364746094|39.28217315673828 |39.46512985229492 |40.082603454589844|1.38808E7 |27.849668502807617|COP   |[39.46512985229492,40.158836364746094,39.28217315673828,1.38808E7]  |
# |12 |2010-01-04|60.06999969482422 |59.130001068115234|59.130001068115234|59.40999984741211 |3280200.0 |46.216087341308594|COST  |[59.130001068115234,60.06999969482422,59.130001068115234,3280200.0] |
# |13 |2010-01-04|28.610000610351562|28.280000686645508|28.40999984741211 |28.579999923706055|2.91366E7 |16.515567779541016|T     |[28.40999984741211,28.610000610351562,28.280000686645508,2.91366E7] |
# |14 |2010-01-04|24.84000015258789 |24.010000228881836|24.110000610351562|24.690000534057617|5.98537E7 |19.253393173217773|CSCO  |[24.110000610351562,24.84000015258789,24.010000228881836,5.98537E7] |
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+--------------------------------------------------------------------+
# only showing top 15 rows

# %% [markdown]
# Por convenção, se altera o nome da coluna que queremos prever seu valor, para label.

# %%
df_novo = df_novo.withColumnRenamed("Close", "label")
df_novo.show()
# Out:
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+--------------------+
# |_c0|      Date|              High|               Low|              Open|             label|    Volume|         Adj Close|Symbol|            features|
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+--------------------+
# |  0|2010-01-04| 30.64285659790039| 30.34000015258789|30.489999771118164|30.572856903076172|1.234324E8| 26.68132972717285|  AAPL|[30.4899997711181...|
# |  1|2010-01-04|34.099998474121094|33.400001525878906|33.599998474121094|              34.0| 4.06793E7|31.601511001586914|     C|[33.5999984741210...|
# |  2|2010-01-04|32.709999084472656| 32.23500061035156|32.290000915527344| 32.69499969482422| 5894200.0|26.618066787719727|   UNP|[32.2900009155273...|
# |  3|2010-01-04|59.189998626708984|  57.5099983215332|57.650001525878906| 58.54999923706055| 7325600.0|  43.9952392578125|   CAT|[57.6500015258789...|
# |  4|2010-01-04| 28.31999969482422|27.665000915527344| 28.31999969482422|  27.8700008392334| 4832000.0|  27.8700008392334|  CELG|[28.3199996948242...|
# |  5|2010-01-04|31.600000381469727|30.969999313354492|  31.3799991607666|31.530000686645508| 1.21995E7|27.110151290893555|   UNH|[31.3799991607666...|
# |  6|2010-01-04|41.439998626708984| 40.93000030517578|41.244998931884766| 41.42499923706055| 4874200.0|32.923980712890625|    CL|[41.2449989318847...|
# |  7|2010-01-04|26.610000610351562|25.889999389648438|26.200000762939453|26.010000228881836| 1.03693E7|20.337688446044922|   TXN|[26.2000007629394...|
# |  8|2010-01-04|   8.5649995803833|             8.375|             8.375| 8.484999656677246| 2.71468E7| 7.081010341644287| CMCSA|[8.375,8.56499958...|
# |  9|2010-01-04|25.700000762939453|25.299999237060547| 25.40999984741211|  25.6299991607666| 1.43761E7| 18.61980438232422|   BMY|[25.4099998474121...|
# | 10|2010-01-04| 39.13999938964844| 38.54999923706055| 38.65999984741211| 39.04999923706055| 4447400.0| 33.58551788330078|   COF|[38.6599998474121...|
# | 11|2010-01-04|40.158836364746094| 39.28217315673828| 39.46512985229492|40.082603454589844| 1.38808E7|27.849668502807617|   COP|[39.4651298522949...|
# | 12|2010-01-04| 60.06999969482422|59.130001068115234|59.130001068115234| 59.40999984741211| 3280200.0|46.216087341308594|  COST|[59.1300010681152...|
# | 13|2010-01-04|28.610000610351562|28.280000686645508| 28.40999984741211|28.579999923706055| 2.91366E7|16.515567779541016|     T|[28.4099998474121...|
# | 14|2010-01-04| 24.84000015258789|24.010000228881836|24.110000610351562|24.690000534057617| 5.98537E7|19.253393173217773|  CSCO|[24.1100006103515...|
# | 15|2010-01-04|33.060001373291016|32.380001068115234| 32.43000030517578| 32.97999954223633| 1.46768E7|27.411426544189453|   CVS|[32.4300003051757...|
# | 16|2010-01-04| 76.34054565429688| 73.80056762695312| 75.71965789794922| 74.24270629882812| 3450400.0|52.846595764160156|   SPG|[75.7196578979492...|
# | 17|2010-01-04| 79.19999694824219| 78.16000366210938| 78.19999694824219| 79.05999755859375| 1.01738E7| 54.99198532104492|   CVX|[78.1999969482421...|
# | 18|2010-01-04| 41.54524230957031|39.566898345947266|40.136207580566406|41.531009674072266| 1.18972E7| 33.75883865356445|    DD|[40.1362075805664...|
# | 19|2010-01-04| 48.88999938964844|48.400001525878906|48.470001220703125| 48.54999923706055| 4589100.0|36.851951599121094|   TGT|[48.4700012207031...|
# +---+----------+------------------+------------------+------------------+------------------+----------+------------------+------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Para facilitar nossa visualização, vamos chamar apenas as colunas label e features, através do select.

# %%
df_novo = df_novo.select("label", "features")
df_novo.show(truncate=False)
# Out:
# +------------------+--------------------------------------------------------------------+
# |label             |features                                                            |
# +------------------+--------------------------------------------------------------------+
# |30.572856903076172|[30.489999771118164,30.64285659790039,30.34000015258789,1.234324E8] |
# |34.0              |[33.599998474121094,34.099998474121094,33.400001525878906,4.06793E7]|
# |32.69499969482422 |[32.290000915527344,32.709999084472656,32.23500061035156,5894200.0] |
# |58.54999923706055 |[57.650001525878906,59.189998626708984,57.5099983215332,7325600.0]  |
# |27.8700008392334  |[28.31999969482422,28.31999969482422,27.665000915527344,4832000.0]  |
# |31.530000686645508|[31.3799991607666,31.600000381469727,30.969999313354492,1.21995E7]  |
# |41.42499923706055 |[41.244998931884766,41.439998626708984,40.93000030517578,4874200.0] |
# |26.010000228881836|[26.200000762939453,26.610000610351562,25.889999389648438,1.03693E7]|
# |8.484999656677246 |[8.375,8.5649995803833,8.375,2.71468E7]                             |
# |25.6299991607666  |[25.40999984741211,25.700000762939453,25.299999237060547,1.43761E7] |
# |39.04999923706055 |[38.65999984741211,39.13999938964844,38.54999923706055,4447400.0]   |
# |40.082603454589844|[39.46512985229492,40.158836364746094,39.28217315673828,1.38808E7]  |
# |59.40999984741211 |[59.130001068115234,60.06999969482422,59.130001068115234,3280200.0] |
# |28.579999923706055|[28.40999984741211,28.610000610351562,28.280000686645508,2.91366E7] |
# |24.690000534057617|[24.110000610351562,24.84000015258789,24.010000228881836,5.98537E7] |
# |32.97999954223633 |[32.43000030517578,33.060001373291016,32.380001068115234,1.46768E7] |
# |74.24270629882812 |[75.71965789794922,76.34054565429688,73.80056762695312,3450400.0]   |
# |79.05999755859375 |[78.19999694824219,79.19999694824219,78.16000366210938,1.01738E7]   |
# |41.531009674072266|[40.136207580566406,41.54524230957031,39.566898345947266,1.18972E7] |
# |48.54999923706055 |[48.470001220703125,48.88999938964844,48.400001525878906,4589100.0] |
# +------------------+--------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# Abaixo nós iremos dividir nosso dataframe na proporção 70/30, onde 70% será nossa base para treinamento do modelo e 30% para testá-lo. Após contaremos as linhas de cada df.

# %%
(trainingData, testeData) = df_novo.randomSplit([0.7, 0.3])
print(trainingData.count(), testeData.count())
# Out:
# 24335 10386

# %%
trainingData.show(10, truncate=False)
testeData.show(10, truncate=False)
# Out:
# +-----------------+-----------------------------------------------------------------+
# |label            |features                                                         |
# +-----------------+-----------------------------------------------------------------+
# |7.018571376800537|[7.2928571701049805,7.357142925262451,6.9314284324646,1.37914E7] |
# |7.269999980926514|[7.29714298248291,7.484285831451416,7.214285850524902,9395400.0] |
# |7.278571605682373|[7.24571418762207,7.407142639160156,7.2328572273254395,1.30312E7]|
# |7.281428337097168|[7.142857074737549,7.311428546905518,6.992856979370117,2.33471E7]|
# |7.314285755157471|[7.25,7.382857322692871,7.242856979370117,5302500.0]             |
# |7.320000171661377|[7.265714168548584,7.492856979370117,7.221428394317627,9685200.0]|
# |7.358571529388428|[7.652857303619385,7.657142639160156,7.258571624755859,2.37531E7]|
# |7.485714435577393|[7.731428623199463,7.757143020629883,7.462857246398926,9955400.0]|
# |7.604285717010498|[7.659999847412109,7.704285621643066,7.528571605682373,6783700.0]|
# |7.605000019073486|[7.724999904632568,7.735000133514404,7.599999904632568,3.1328E7] |
# +-----------------+-----------------------------------------------------------------+
# only showing top 10 rows
#
# +-----------------+------------------------------------------------------------------+
# |label            |features                                                          |
# +-----------------+------------------------------------------------------------------+
# |7.135714054107666|[6.960000038146973,7.1785712242126465,6.937142848968506,1.13435E7]|
# |7.284285545349121|[7.518571376800537,7.575714111328125,7.269999980926514,1.76855E7] |
# |7.312857151031494|[7.2171430587768555,7.454285621643066,7.214285850524902,8614900.0]|
# |7.481428623199463|[7.528571605682373,7.582857131958008,7.451428413391113,6330100.0] |
# |7.617142677307129|[7.361428737640381,7.672857284545898,7.197143077850342,2.32904E7] |
# |7.829999923706055|[7.885000228881836,7.885000228881836,7.800000190734863,2.67982E7] |
# |7.835000038146973|[7.795000076293945,7.855000019073486,7.724999904632568,4.04746E7] |
# |7.864999771118164|[7.849999904632568,7.900000095367432,7.800000190734863,2.54326E7] |
# |7.925000190734863|[7.815000057220459,8.045000076293945,7.789999961853027,4.078E7]   |
# |7.925000190734863|[8.005000114440918,8.1899995803833,7.90500020980835,5.6665E7]     |
# +-----------------+------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Aqui nós iremos importar da biblioteca, as técnicas de regressão linear.

# %%
from pyspark.ml.regression import LinearRegression, LinearRegressionTrainingSummary
from pyspark.ml.evaluation import RegressionEvaluator

# %% [markdown]
# Abaixo atribuímos ao objeto lr a técnica de Regressão Linear.

# %%
from pyspark.ml.regression import LinearRegression, LinearRegressionTrainingSummary
from pyspark.ml.evaluation import RegressionEvaluator

# %% [markdown]
# Abaixo atribuímos ao objeto lr a técnica de Regressão Linear.

# %%
lr = LinearRegression()

# %% [markdown]
# Abaixo nós iremos pegar nossa base de testes que dividimos anteriormente e treiná-la com nossa técnica de regressão linear, que atribuímos ao objeto lr acima.

# %%
lrModelo = lr.fit(trainingData)

# %% [markdown]
# Feito o treinameento acima, abaixo iremos verificar os parâmetros para avaliar nosso modelo. A técnica de Regressão Linear, nos traz os sequintes parâmetros:
#
#
# - Coefficients
# - Interceptor
# - Mean Squared Error
# - Root Mean Squared Error --> quanto menor, melhor.
# - Root Squared --> quanto mais próximo de 1, melhor.

# %% [markdown]
# Esses parâmetros são de nossa base de treinamento.

# %%
resultado = lrModelo.summary
print("Coefficients: %s" % str(lrModelo.coefficients))
print("Intercept: %s" % str(lrModelo.intercept))
print(resultado.meanSquaredError)
print(resultado.rootMeanSquaredError)
print(resultado.r2)
# Out:
# Coefficients: [-0.5412340802981839,0.8478774027358718,0.6919976694586922,-3.0786189625971426e-10]
# Intercept: 0.027450418605165294
# 0.23144304169797777
# 0.48108527487128283
# 0.9999274918978792

# %% [markdown]
# Testando nosso modelo usando nossa base de testes.

# %%
df_resultado = lrModelo.transform(testeData)
df_resultado.show(10, truncate=False)
# Out:
# +-----------------+------------------------------------------------------------------+------------------+
# |label            |features                                                          |prediction        |
# +-----------------+------------------------------------------------------------------+------------------+
# |7.135714054107666|[6.960000038146973,7.1785712242126465,6.937142848968506,1.13435E7]|7.144003976791267 |
# |7.281428337097168|[7.142857074737549,7.311428546905518,6.992856979370117,2.33471E7] |7.192540835801276 |
# |7.284285545349121|[7.518571376800537,7.575714111328125,7.269999980926514,1.76855E7] |7.406798511108243 |
# |7.314285755157471|[7.25,7.382857322692871,7.242856979370117,5302500.0]              |7.3736689402195035|
# |7.614285945892334|[7.498571395874023,7.742856979370117,7.465714454650879,8180900.0] |7.697699907108041 |
# |7.664999961853027|[7.630000114440918,7.715000152587891,7.554999828338623,3.6472E7]  |7.656022550364536 |
# |7.710000038146973|[7.755000114440918,7.864999771118164,7.574999809265137,5.34312E7] |7.724168426017401 |
# |7.809999942779541|[7.985000133514404,8.0600004196167,7.775000095367432,3.86188E7]   |7.907981126032364 |
# |7.829999923706055|[7.885000228881836,7.885000228881836,7.800000190734863,2.67982E7] |7.834664895308954 |
# |7.925000190734863|[7.815000057220459,8.045000076293945,7.789999961853027,4.078E7]   |7.996987030359322 |
# +-----------------+------------------------------------------------------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# Agora vamos avaliar se nosso modelo treinado com nossa base de testes, através da métrica RMSE, obteve bom desempenho.

# %% [markdown]
# Pedemos verificar que nosso modelo teve uma leve piora, quando testado com nossa base de treinamento, pois o valor encontrado utilizando a mesma métrica (RMSE) subiu um pouquinho.

# %%
evaluator = RegressionEvaluator(labelCol="label", predictionCol="prediction", metricName="rmse")
rmse= evaluator.evaluate(df_resultado)
print("Root mean Squared Error (RMSE) on teste data = %g" % rmse)
# Out:
# Root mean Squared Error (RMSE) on teste data = 0.509102

# %% [markdown]
# Agora iremos testar nosso modelo com dados desconhecidos.
#
# Suponhamos que uma determinada ação, teve sua abertura com valor 20, uma máxima de 22, uma mínima de 19 e com um volume até entao de ações negociadas de 7.400,300. Vamos ver qual será o valor que nosso modelo irá prever de fechamento?
#
# Iremos usar a técnica de vetor denso e informar os valores que mencionamos acima.

# %%
nova_acao = Vectors.dense(20, 22, 19, 7400300)
print(lrModelo.predict(nova_acao))
# Out:
# 21.001749122154926

# %% [markdown]
# **Considerações Finais**

# %% [markdown]
# De uma maneira geral, e digo porque também faço operações na bolsa de valores, o resultado do modelo está parecendo satisfatório, fazendo sentido, teria que testar para conferir.
#
# Melhorias como aumentar os números de atributos, como por exemplo, adicionar o ajuste de fechamento, tendencia do ativo e min e max semanal, valem muito a pena considerar e testar, mas de certa forma achei que as previsões de fechamento foram boas, realistas, como os parâmetros do modelo de Regressão Linear, mostraram.
